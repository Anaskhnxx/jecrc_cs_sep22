# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
df1 = pd.read_csv('df1')
df2 = pd.read_csv('df2')
df3 = pd.read_csv('df3')

# %%
df1.head()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1000 non-null   object
#  1   A           1000 non-null   float64
#  2   B           1000 non-null   float64
#  3   C           1000 non-null   float64
#  4   D           1000 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 39.2+ KB

# %%
df2.head()
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       10 non-null     float64
#  1   b       10 non-null     float64
#  2   c       10 non-null     float64
#  3   d       10 non-null     float64
# dtypes: float64(4)
# memory usage: 448.0 bytes

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df3.head()
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %% [markdown]
# # graph function :
# 1. plot                             - simple line plot
# 2. plot.area                        - filled version of line plot
# 3. plot.bar / plot.barh             - bar graph
# 4. plot.box                         - box plot
# 5. plot.density                     - density lne (smooth curved)
# 6. plot.hexbin                      - hexagon version of scatter with density
# 7. plot.hist                        - histogram
# 8. plot.kde                         - kernel density estimator (density graph)
# 9. plot.pie                        - pie chart of categorical
# 10. plot.scatter                    - scatter graph

# %%
fig = plt.figure(figsize = (20,20))
df2.plot(); plt.title('Line Plot')
df2.plot.area(); plt.title('Area Plot') 
df2.plot.bar(); plt.title('Bar Plot') 
df2.plot.box(); plt.title('Box Plot') 
df2.plot.barh(); plt.title('Bar Horizontal Plot') 
df2.plot.density(); plt.title('Density Plot') 
df2.plot.kde(); plt.title('KDE Plot') 
df2.plot.hist(); plt.title('Histogram Plot') 
df2.plot.scatter(x='a', y= 'b' ); plt.title('Scatter Plot') 
df2.plot.hexbin(x='a', y='b' , C='c' , gridsize=6); plt.title('Hexbin Plot')
# Out:
# Text(0.5, 1.0, 'Hexbin Plot')

# %%
df1.plot.scatter(x = 'A' , y='B')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df4 = pd.DataFrame({'gift': [40,50,60,70], 'Name' : ['anas', 'awasthi' , 'aakash' , 'yash']})

# %%
df4
# Out:
#    gift     Name
# 0    40     anas
# 1    50  awasthi
# 2    60   aakash
# 3    70     yash

# %%
df4.plot.line()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (5,5))
df4['gift'].plot.pie(autopct = '%d%%' , labels = df4['Name'])
# Out:
# <AxesSubplot:ylabel='gift'>

# %% [markdown]
# # SEABORN

# %%
import seaborn as sns

# %% [markdown]
# ##### Categories of function
# 1. categorical plot (hue can be used | comparison with catogorical data)
#    1. countplot     (single parameter)
#    2. barplot       (one parammeter catogorical and one parameter numerical | calculates mean by default )
#    3. boxplot
#    4. violinplot
#    5. swarmplot
# 2. distribution plot
#    1. distplot
#    2. displot
#    3. jointplot
#    4. pairplot
#    5. kdeplot
#    6. rugplot
#    7. scatterplot
# 3. matrix plot
#    1. heatmap
#    2. clustermap
#    3. pairplot(regression also draw in pairplot)(same as above me)
# 4. regression plot
#    1. implot
#    2. regplot
# 5. grid plots
#    1. PairGrid
#    2. JointGrid
#    3. FacetGrid

# %%
tips = sns.load_dataset('tips')
sns.set_style('dark')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.describe(include = 'all')
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %%
tips['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
tips.groupby(['sex' , 'time'])['day'].value_counts().sort_index()
# Out:
# sex     time
# Male    Lunch   Thur    30
#                 Fri      3
#                 Sat      0
#                 Sun      0
#         Dinner  Thur     0
#                 Fri      7
#                 Sat     59
#                 Sun     58
# Female  Lunch   Thur    31
#                 Fri      4
#                 Sat      0
#                 Sun      0
#         Dinner  Thur     1
#                 Fri      5
#                 Sat     28
#                 Sun     18
# Name: day, dtype: int64

# %%
sns.countplot(x='day' , data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.countplot(x='day' , data=tips , hue = 'sex')
# hue ------ same as a groupby function
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.barplot(x = 'day' , y = 'total_bill', data = tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x = 'day' , y = 'total_bill', data = tips , estimator=sum)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x = 'day' , y = 'total_bill', data = tips , hue = 'time' ,estimator=np.mean)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x = 'day' , y = 'total_bill', data = tips , hue = 'smoker' )
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x = 'day' , y = 'total_bill', data = tips , hue = 'smoker' )
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x = 'day' , y = 'total_bill', data = tips , hue = 'smoker' )
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
import warnings
warnings.filterwarnings('ignore')
sns.distplot(tips['total_bill'] )
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>
